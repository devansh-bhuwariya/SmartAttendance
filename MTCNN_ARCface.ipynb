# %%
# !pip install ultralytics -q
# !pip install gradio -q
# !pip install pandas -q
# !pip install deepface -q
# !pip install pillow -q
# !pip install opencv-python -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.1/755.1 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 78.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.4/314.4 kB 34.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 94.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 35.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 37.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.8 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 12.3 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done

# %%
# !unzip /content/attendancesystem.zip
# Out:
# unzip:  cannot find or open /content/attendancesystem.zip, /content/attendancesystem.zip.zip or /content/attendancesystem.zip.ZIP.

# %%
# Import necessary libraries
from ultralytics import YOLO
from ultralytics.engine.results import Results
from deepface import DeepFace
from PIL import Image
import gradio as gr
import shutil
import pandas
import cv2
import os
# Out:
# 24-05-03 08:51:01 - Directory /root/.deepface created
# 24-05-03 08:51:01 - Directory /root/.deepface/weights created

# %%
def faceRecognition(input_image):
    # Path to the directory containing cropped objects
    cropped_objects_dir = "/content/faces"

    # Initialize lists to store the extracted names and predicted image filenames
    extracted_names = []
    predicted_image_filenames = []

    file_to_delete = "./database/representations_ArcFace.pkl"
    if os.path.exists(file_to_delete):
        os.remove(file_to_delete)

    # Iterate through the image files in the directory
    for filename in os.listdir(cropped_objects_dir):
        if filename.endswith(".jpg"):
            img_path = os.path.join(cropped_objects_dir, filename)
            model = DeepFace.find(img_path=img_path, db_path="/content/attendancesystem/database", enforce_detection=False, model_name="ArcFace")

            # Check if a face was recognized in the image
            if model and len(model[0]['identity']) > 0:
                # Extract the name and append it to the list
                name = model[0]['identity'][0].split('/')[4]
                extracted_names.append(name)
                # Append the predicted image filename to the list
                predicted_image_filenames.append(filename)
            else:
                # If no face is recognized, set name to 'unknown'
                name = 'unknown'
                extracted_names.append(name)
                # Append the predicted image filename to the list
                predicted_image_filenames.append(filename)

    return extracted_names, predicted_image_filenames

# %%
def faceExtraction(input_image, model, results):
    # Load the image
    image = input_image

    detected_faces = []

    if results:
        for result in results:
            x, y, width, height = result['box']
            x1, y1, x2, y2 = x, y, x + width, y + height
            detected_faces.append(('face', (x1, y1, x2, y2)))

    # Create or clear the 'faces' directory
    if os.path.exists("faces"):
        shutil.rmtree("faces")
    os.makedirs("faces")

    # Crop and save each detected face
    for i, (object_name, (x1, y1, x2, y2)) in enumerate(detected_faces):
        face_image = image[y1:y2, x1:x2]
        cv2.imwrite(f"faces/face{i}.jpg", face_image)

    return detected_faces

# %%
import cv2
from mtcnn import MTCNN
def faceDetection(image_path):
    # Load the input image using OpenCV
    input_image = cv2.imread(image_path)

    if input_image is None:
        print("Error: Unable to load the input image.")
        return

    # Create an instance of the MTCNN detector
    detector_mtcnn = MTCNN()

    # Detect faces in the input image
    results = detector_mtcnn.detect_faces(input_image)

    return faceExtraction(input_image, detector_mtcnn, results)

# %%
image = input("enter image path : ")
faceDetection(image)
names, image = faceRecognition(image)
print(names)
print(image)
# Out:
# enter image path : /content/attendancesystem/classroom3.jpg
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 655ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 33/33 [==============================] - 2s 9ms/step
# 5/5 [==============================] - 1s 31ms/step
# 24-05-03 08:51:55 - Found 400 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations:   0%|          | 0/400 [00:00<?, ?it/s]
# 24-05-03 08:51:59 - arcface_weights.h5 will be downloaded to /root/.deepface/weights/arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /root/.deepface/weights/arcface_weights.h5
#
#   0%|          | 0.00/137M [00:00<?, ?B/s]
#   1%|          | 1.57M/137M [00:00<00:10, 13.4MB/s]
#   3%|▎         | 4.72M/137M [00:00<00:05, 22.1MB/s]
#   7%|▋         | 9.96M/137M [00:00<00:03, 35.0MB/s]
#  15%|█▍        | 19.9M/137M [00:00<00:01, 59.3MB/s]
#  25%|██▍       | 34.1M/137M [00:00<00:01, 86.4MB/s]
#  31%|███▏      | 43.0M/137M [00:00<00:01, 76.5MB/s]
#  37%|███▋      | 51.4M/137M [00:00<00:01, 71.4MB/s]
#  43%|████▎     | 58.7M/137M [00:00<00:01, 68.6MB/s]
#  48%|████▊     | 66.1M/137M [00:01<00:01, 66.7MB/s]
#  53%|█████▎    | 72.9M/137M [00:01<00:00, 65.5MB/s]
#  58%|█████▊    | 79.7M/137M [00:01<00:00, 64.6MB/s]
#  63%|██████▎   | 86.5M/137M [00:01<00:00, 63.9MB/s]
#  68%|██████▊   | 93.3M/137M [00:01<00:00, 63.3MB/s]
#  73%|███████▎  | 100M/137M [00:01<00:00, 63.1MB/s]
#  78%|███████▊  | 107M/137M [00:01<00:00, 62.7MB/s]
#  83%|████████▎ | 113M/137M [00:01<00:00, 62.3MB/s]
#  87%|████████▋ | 120M/137M [00:01<00:00, 62.2MB/s]
#  92%|█████████▏| 126M/137M [00:02<00:00, 62.3MB/s]
# 100%|██████████| 137M/137M [00:02<00:00, 62.6MB/s]
# Finding representations: 100%|██████████| 400/400 [03:48<00:00,  1.75it/s]
# 24-05-03 08:55:44 - There are now 400 representations in ds_model_arcface_detector_opencv_aligned_normalization_base_expand_0.pkl
# 24-05-03 08:55:44 - Searching /content/faces/face12.jpg in 400 length datastore
# 24-05-03 08:55:44 - find function duration 228.68188500404358 seconds
# 24-05-03 08:55:44 - Searching /content/faces/face17.jpg in 400 length datastore
# 24-05-03 08:55:45 - find function duration 0.5004715919494629 seconds
# 24-05-03 08:55:45 - Searching /content/faces/face19.jpg in 400 length datastore
# 24-05-03 08:55:45 - find function duration 0.8618464469909668 seconds
# 24-05-03 08:55:46 - Searching /content/faces/face8.jpg in 400 length datastore
# 24-05-03 08:55:46 - find function duration 0.8598599433898926 seconds
# 24-05-03 08:55:46 - Searching /content/faces/face14.jpg in 400 length datastore
# 24-05-03 08:55:47 - find function duration 0.8790996074676514 seconds
# 24-05-03 08:55:47 - Searching /content/faces/face28.jpg in 400 length datastore
# 24-05-03 08:55:48 - find function duration 0.5340642929077148 seconds
# 24-05-03 08:55:48 - Searching /content/faces/face0.jpg in 400 length datastore
# 24-05-03 08:55:48 - find function duration 0.5318162441253662 seconds
# 24-05-03 08:55:48 - Searching /content/faces/face15.jpg in 400 length datastore
# 24-05-03 08:55:49 - find function duration 0.505824089050293 seconds
# 24-05-03 08:55:49 - Searching /content/faces/face23.jpg in 400 length datastore
# 24-05-03 08:55:49 - find function duration 0.5236811637878418 seconds
# 24-05-03 08:55:49 - Searching /content/faces/face13.jpg in 400 length datastore
# 24-05-03 08:55:50 - find function duration 0.48380327224731445 seconds
# 24-05-03 08:55:50 - Searching /content/faces/face25.jpg in 400 length datastore
# 24-05-03 08:55:50 - find function duration 0.5006515979766846 seconds
# 24-05-03 08:55:50 - Searching /content/faces/face4.jpg in 400 length datastore
# 24-05-03 08:55:51 - find function duration 0.4971804618835449 seconds
# 24-05-03 08:55:51 - Searching /content/faces/face9.jpg in 400 length datastore
# 24-05-03 08:55:51 - find function duration 0.5124080181121826 seconds
# 24-05-03 08:55:51 - Searching /content/faces/face11.jpg in 400 length datastore
# 24-05-03 08:55:52 - find function duration 0.5034914016723633 seconds
# 24-05-03 08:55:52 - Searching /content/faces/face1.jpg in 400 length datastore
# 24-05-03 08:55:52 - find function duration 0.5349733829498291 seconds
# 24-05-03 08:55:52 - Searching /content/faces/face27.jpg in 400 length datastore
# 24-05-03 08:55:53 - find function duration 0.502206563949585 seconds
# 24-05-03 08:55:53 - Searching /content/faces/face16.jpg in 400 length datastore
# 24-05-03 08:55:53 - find function duration 0.5110938549041748 seconds
# 24-05-03 08:55:54 - Searching /content/faces/face21.jpg in 400 length datastore
# 24-05-03 08:55:54 - find function duration 0.5034894943237305 seconds
# 24-05-03 08:55:54 - Searching /content/faces/face10.jpg in 400 length datastore
# 24-05-03 08:55:54 - find function duration 0.5084373950958252 seconds
# 24-05-03 08:55:55 - Searching /content/faces/face6.jpg in 400 length datastore
# 24-05-03 08:55:55 - find function duration 0.5074822902679443 seconds
# 24-05-03 08:55:55 - Searching /content/faces/face26.jpg in 400 length datastore
# 24-05-03 08:55:55 - find function duration 0.5085351467132568 seconds
# 24-05-03 08:55:56 - Searching /content/faces/face18.jpg in 400 length datastore
# 24-05-03 08:55:56 - find function duration 0.4902520179748535 seconds
# 24-05-03 08:55:56 - Searching /content/faces/face20.jpg in 400 length datastore
# 24-05-03 08:55:57 - find function duration 0.5382869243621826 seconds
# 24-05-03 08:55:57 - Searching /content/faces/face29.jpg in 400 length datastore
# 24-05-03 08:55:57 - find function duration 0.49944090843200684 seconds
# 24-05-03 08:55:57 - Searching /content/faces/face3.jpg in 400 length datastore
# 24-05-03 08:55:58 - find function duration 0.7133641242980957 seconds
# 24-05-03 08:55:58 - Searching /content/faces/face22.jpg in 400 length datastore
# 24-05-03 08:55:59 - find function duration 0.8562378883361816 seconds
# 24-05-03 08:55:59 - Searching /content/faces/face24.jpg in 400 length datastore
# 24-05-03 08:55:59 - find function duration 0.8457245826721191 seconds
# 24-05-03 08:56:00 - Searching /content/faces/face2.jpg in 400 length datastore
# 24-05-03 08:56:00 - find function duration 0.7020468711853027 seconds
# 24-05-03 08:56:00 - Searching /content/faces/face5.jpg in 400 length datastore
# 24-05-03 08:56:01 - find function duration 0.5066156387329102 seconds
# 24-05-03 08:56:01 - Searching /content/faces/face7.jpg in 400 length datastore
# 24-05-03 08:56:01 - find function duration 0.5046918392181396 seconds
# ['60009220174', '60009220088', '60009210206', '60009210196', '60009210190', '60009210193', '60009210197', '60009210124', '60009210202', '60009210126', '60009210188', '60009210123', '60009210157', '60009220175', '60009210164', '60009210204', '60009220080', '60009210145', '60009210187', '60009210140', '60009210192', '60009210156', '60009220194', '60009210194', '60009210173', '60009210161', '60009210209', '60009210185', '60009210178', '60009210175']
# ['face12.jpg', 'face17.jpg', 'face19.jpg', 'face8.jpg', 'face14.jpg', 'face28.jpg', 'face0.jpg', 'face15.jpg', 'face23.jpg', 'face13.jpg', 'face25.jpg', 'face4.jpg', 'face9.jpg', 'face11.jpg', 'face1.jpg', 'face27.jpg', 'face16.jpg', 'face21.jpg', 'face10.jpg', 'face6.jpg', 'face26.jpg', 'face18.jpg', 'face20.jpg', 'face29.jpg', 'face3.jpg', 'face22.jpg', 'face24.jpg', 'face2.jpg', 'face5.jpg', 'face7.jpg']

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_predicted_images(image_list, names, folder_path):
    num_images = len(image_list)

    # Create a grid of subplots with two columns
    fig, axes = plt.subplots(num_images, 2, figsize=(5, 5*num_images))

    # Iterate over images and corresponding names
    for i, (image_name, predicted_label) in enumerate(zip(image_list, names)):
        # Load and plot image
        img_path = os.path.join(folder_path, image_name)
        img = mpimg.imread(img_path)
        axes[i, 0].imshow(img)
        axes[i, 0].axis('off')

        # Set title as the predicted label
        axes[i, 1].text(0.5, 0.5, predicted_label, fontsize=20, ha='center', va='center')

        # Remove axis from the label subplot
        axes[i, 1].axis('off')

    plt.tight_layout()  # Adjust spacing between subplots
    plt.show()

# Example usage
image_list = image

folder_path = '/content/faces'

# Plot predicted images
plot_predicted_images(image_list, names, folder_path)
